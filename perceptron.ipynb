# %% [markdown]
# ## Perceptron Learning Algorithm
#
# The perceptron is a simple supervised machine learning algorithm and one of the earliest neural network architectures. It was introduced by Rosenblatt in the late 1950s. A perceptron represents a binary linear classifier that maps a set of training examples (of $d$ dimensional input vectors) onto binary output values using a $d-1$ dimensional hyperplane. But Today, we will implement **Multi-Classes Perceptron Learning Algorithm**
# **Given:**
# * dataset $\{(x^i, y^i)\}$, $i \in (1, M)$
# * $x^i$ is $d$ dimension vector, $x^i = (x^i_1, \dots x^i_d)$
# * $y^i$ is multi-class target varible $y^i \in \{0,1,2\}$
#
# A perceptron is trained using gradient descent. The training algorithm has different steps. In the beginning (step 0) the model parameters are initialized. The other steps (see below) are repeated for a specified number of training iterations or until the parameters have converged.
#
# **Step0:** Initial the weight vector and bias with zeros
# **Step1:** Compute the linear combination of the input features and weight. $y^i_{pred} = \arg\max_k W_k*x^i + b$
# **Step2:** Compute the gradients for parameters $W_k$, $b$. **Derive the parameter update equation Here (5 points)**
#
# ##################################
# TODO: Derive you answer hear
# #################################
#
# if y_predict==y:
#
#                 accuracy+=1
#
#             else:
#
#                 weight_true_vector+=learning_rate*x
#
#                 weight_predict_vector-=learning_rate*x
#
#               bias+=learning_rate*(weight_true_vector-weight_predict_vector)

# %%
from sklearn import datasets
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random

np.random.seed(0)
random.seed(0)

# %%
iris = datasets.load_iris()
X = iris.data
print(type(X))
y = iris.target
y = np.array(y)
print('X_Shape:', X.shape)
print('y_Shape:', y.shape)
print('Label Space:', np.unique(y))
# Out:
# <class 'numpy.ndarray'>
# X_Shape: (150, 4)
# y_Shape: (150,)
# Label Space: [0 1 2]

# %%
## split the training set and test set
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3, random_state=0)
print('X_train_Shape:', X_train.shape)
print('X_test_Shape:',  X_test.shape)
print('y_train_Shape:', y_train.shape)
print('y_test_Shape:',  y_train.shape)

print(type(y_train))
# Out:
# X_train_Shape: (105, 4)
# X_test_Shape: (45, 4)
# y_train_Shape: (105,)
# y_test_Shape: (105,)
# <class 'numpy.ndarray'>

# %%
class MultiClsPLA(object):
    
    ## We recommend to absorb the bias into weight.  W = [w, b]
    
    def __init__(self, X_train, y_train, X_test, y_test, lr, num_epoch, weight_dimension, num_cls):
        super(MultiClsPLA, self).__init__()
        self.X_train = X_train
        self.y_train = y_train
        self.X_test = X_test
        self.y_test = y_test
        self.weight = self.initial_weight(weight_dimension, num_cls)
        self.sample_mean = np.mean(self.X_train, 0)
        self.sample_std = np.std(self.X_train, 0)
        self.num_epoch = num_epoch
        self.lr = lr
        self.total_acc_train = []
        self.total_acc_tst = []
          
    def initial_weight(self, weight_dimension, num_cls):
        weight = np.random.normal(loc=0,scale=0.01,size=(weight_dimension+1,num_cls))
        #########################################
        ##  ToDO: Initialize the weight with   ##
        ##  small std and zero mean gaussian   ##
        #########################################
     
        return weight
        
    def data_preprocessing(self, data):
        #####################################
        ##  ToDO: Normlize the data        ##
        #####################################
        norm_data = (data-self.sample_mean)/self.sample_std
        return norm_data
    
    def train_step(self, X_train, y_train, shuffle_idx):
        np.random.shuffle(shuffle_idx)
        X_train = X_train[shuffle_idx]
        y_train = y_train[shuffle_idx]
        train_acc = 0
        cmp=0
        num_sample = X_test.shape[0]
        ##############################################
        ## TODO: to implement the training process  ##
        ## and update the weights                   ##
        ##############################################

        for num in range(num_sample):

            y_pred=np.dot(X_train[num],self.weight[0:-1])+self.weight[-1]
            predict_result=int(np.argmax(y_pred))
            if predict_result==y_train[num]:
                cmp+=1
            else:
                self.weight[0:-1,y_train[num]]+=self.lr*X_train[num]
                self.weight[0:-1,predict_result]-=self.lr*X_train[num]
                self.weight[:1]+=self.lr*(y_train[num]-predict_result)
            train_acc=cmp/num_sample
            

        return train_acc
        
    def test_step(self, X_test, y_test):
      
        X_test = self.data_preprocessing(data=X_test)
        num_sample = X_test.shape[0]
        test_acc = 0

        #########################################
        ##  ToDO: Evaluate the test set and    ##
        ##  return the test acc                ##
        #########################################
        cmp = 0

        for num in range(num_sample):

            y_pred = np.dot(X_test[num], self.weight[0:-1]) + self.weight[-1]
            predict_result = int(np.argmax(y_pred))
            if predict_result == y_test[num]:
                cmp += 1
            test_acc = cmp / num_sample
        return test_acc
    def train(self):
           
        self.X_train = self.data_preprocessing(data=self.X_train)
        num_sample = self.X_train.shape[0]
        self.X_test = self.data_preprocessing(data=self.X_test)
        ######################################################
        ### TODO: In order to absorb the bias into weights ###
        ###  we need to modify the input data.             ###
        ###  So You need to transform the input data       ###
        ######################################################
         
        
        shuffle_index = np.array(range(0, num_sample))
        for epoch in range(self.num_epoch):
            training_acc = self.train_step(X_train=self.X_train, y_train=self.y_train, shuffle_idx=shuffle_index)
            tst_acc = self.test_step(X_test=self.X_test,  y_test=self.y_test)
            self.total_acc_train.append(training_acc)
            self.total_acc_tst.append(tst_acc)
            print('epoch:', epoch, 'traing_acc:%.3f'%training_acc, 'tst_acc:%.3f'%tst_acc)
    
    def vis_acc_curve(self):
        train_acc = np.array(self.total_acc_train)
        tst_acc = np.array(self.total_acc_tst)
        plt.plot(train_acc)
        plt.plot(tst_acc)
        plt.legend(['train_acc', 'tst_acc'])
        plt.show()

# %%
np.random.seed(0)
random.seed(0)
#######################################################
### TODO: 
### 1. You need to import the model and pass some parameters. 
### 2. Then training the model with some epoches.
### 3. Visualize the training acc and test acc verus epoches
net = MultiClsPLA(X_train, y_train, X_test, y_test, lr=0.01, num_epoch=200,
 weight_dimension=4, num_cls=3)
net.train()
print(net.weight)
print(net.weight[:,0])
net.vis_acc_curve()
# Out:
# epoch: 0 traing_acc:0.711 tst_acc:0.733
# epoch: 1 traing_acc:0.778 tst_acc:0.578
# epoch: 2 traing_acc:0.822 tst_acc:0.600
# epoch: 3 traing_acc:0.800 tst_acc:0.778
# epoch: 4 traing_acc:0.733 tst_acc:0.511
# epoch: 5 traing_acc:0.756 tst_acc:0.689
# epoch: 6 traing_acc:0.867 tst_acc:0.822
# epoch: 7 traing_acc:0.800 tst_acc:0.444
# epoch: 8 traing_acc:0.867 tst_acc:0.489
# epoch: 9 traing_acc:0.911 tst_acc:0.778
# epoch: 10 traing_acc:0.756 tst_acc:0.600
# epoch: 11 traing_acc:0.867 tst_acc:0.489
# epoch: 12 traing_acc:0.778 tst_acc:0.911
# epoch: 13 traing_acc:0.711 tst_acc:0.733
# epoch: 14 traing_acc:0.756 tst_acc:0.711
# epoch: 15 traing_acc:0.778 tst_acc:0.689
# epoch: 16 traing_acc:0.844 tst_acc:0.711
# epoch: 17 traing_acc:0.756 tst_acc:0.822
# epoch: 18 traing_acc:0.822 tst_acc:0.489
# epoch: 19 traing_acc:0.800 tst_acc:0.778
# epoch: 20 traing_acc:0.733 tst_acc:0.556
# epoch: 21 traing_acc:0.867 tst_acc:0.711
# epoch: 22 traing_acc:0.800 tst_acc:0.711
# epoch: 23 traing_acc:0.822 tst_acc:0.689
# epoch: 24 traing_acc:0.778 tst_acc:0.556
# epoch: 25 traing_acc:0.822 tst_acc:0.756
# epoch: 26 traing_acc:0.800 tst_acc:0.600
# epoch: 27 traing_acc:0.800 tst_acc:0.689
# epoch: 28 traing_acc:0.867 tst_acc:0.600
# epoch: 29 traing_acc:0.800 tst_acc:0.556
# epoch: 30 traing_acc:0.822 tst_acc:0.489
# epoch: 31 traing_acc:0.844 tst_acc:0.689
# epoch: 32 traing_acc:0.911 tst_acc:0.822
# epoch: 33 traing_acc:0.800 tst_acc:0.422
# epoch: 34 traing_acc:0.889 tst_acc:0.711
# epoch: 35 traing_acc:0.778 tst_acc:0.556
# epoch: 36 traing_acc:0.800 tst_acc:0.556
# epoch: 37 traing_acc:0.867 tst_acc:0.422
# epoch: 38 traing_acc:0.822 tst_acc:0.422
# epoch: 39 traing_acc:0.800 tst_acc:0.778
# epoch: 40 traing_acc:0.756 tst_acc:0.422
# epoch: 41 traing_acc:0.756 tst_acc:0.644
# epoch: 42 traing_acc:0.778 tst_acc:0.444
# epoch: 43 traing_acc:0.822 tst_acc:0.711
# epoch: 44 traing_acc:0.844 tst_acc:0.578
# epoch: 45 traing_acc:0.756 tst_acc:0.378
# epoch: 46 traing_acc:0.756 tst_acc:0.822
# epoch: 47 traing_acc:0.867 tst_acc:0.778
# epoch: 48 traing_acc:0.800 tst_acc:0.511
# epoch: 49 traing_acc:0.844 tst_acc:0.711
# epoch: 50 traing_acc:0.756 tst_acc:0.733
# epoch: 51 traing_acc:0.800 tst_acc:0.756
# epoch: 52 traing_acc:0.800 tst_acc:0.756
# epoch: 53 traing_acc:0.911 tst_acc:0.756
# epoch: 54 traing_acc:0.844 tst_acc:0.600
# epoch: 55 traing_acc:0.711 tst_acc:0.556
# epoch: 56 traing_acc:0.867 tst_acc:0.667
# epoch: 57 traing_acc:0.800 tst_acc:0.600
# epoch: 58 traing_acc:0.733 tst_acc:0.733
# epoch: 59 traing_acc:0.733 tst_acc:0.822
# epoch: 60 traing_acc:0.800 tst_acc:0.756
# epoch: 61 traing_acc:0.778 tst_acc:0.511
# epoch: 62 traing_acc:0.800 tst_acc:0.756
# epoch: 63 traing_acc:0.822 tst_acc:0.600
# epoch: 64 traing_acc:0.844 tst_acc:0.711
# epoch: 65 traing_acc:0.911 tst_acc:0.711
# epoch: 66 traing_acc:0.800 tst_acc:0.689
# epoch: 67 traing_acc:0.867 tst_acc:0.778
# epoch: 68 traing_acc:0.778 tst_acc:0.622
# epoch: 69 traing_acc:0.867 tst_acc:0.689
# epoch: 70 traing_acc:0.844 tst_acc:0.689
# epoch: 71 traing_acc:0.844 tst_acc:0.711
# epoch: 72 traing_acc:0.844 tst_acc:0.600
# epoch: 73 traing_acc:0.800 tst_acc:0.711
# epoch: 74 traing_acc:0.867 tst_acc:0.822
# epoch: 75 traing_acc:0.822 tst_acc:0.933
# epoch: 76 traing_acc:0.911 tst_acc:0.689
# epoch: 77 traing_acc:0.844 tst_acc:0.622
# epoch: 78 traing_acc:0.756 tst_acc:0.600
# epoch: 79 traing_acc:0.733 tst_acc:0.778
# epoch: 80 traing_acc:0.800 tst_acc:0.600
# epoch: 81 traing_acc:0.889 tst_acc:0.756
# epoch: 82 traing_acc:0.822 tst_acc:0.711
# epoch: 83 traing_acc:0.844 tst_acc:0.600
# epoch: 84 traing_acc:0.800 tst_acc:0.733
# epoch: 85 traing_acc:0.822 tst_acc:0.933
# epoch: 86 traing_acc:0.822 tst_acc:0.600
# epoch: 87 traing_acc:0.667 tst_acc:0.689
# epoch: 88 traing_acc:0.889 tst_acc:0.711
# epoch: 89 traing_acc:0.844 tst_acc:0.689
# epoch: 90 traing_acc:0.778 tst_acc:0.600
# epoch: 91 traing_acc:0.778 tst_acc:0.689
# epoch: 92 traing_acc:0.844 tst_acc:0.778
# epoch: 93 traing_acc:0.778 tst_acc:0.489
# epoch: 94 traing_acc:0.844 tst_acc:0.711
# epoch: 95 traing_acc:0.800 tst_acc:0.711
# epoch: 96 traing_acc:0.778 tst_acc:0.778
# epoch: 97 traing_acc:0.822 tst_acc:0.711
# epoch: 98 traing_acc:0.867 tst_acc:0.711
# epoch: 99 traing_acc:0.800 tst_acc:0.600
# epoch: 100 traing_acc:0.889 tst_acc:0.556
# epoch: 101 traing_acc:0.756 tst_acc:0.733
# epoch: 102 traing_acc:0.844 tst_acc:0.756
# epoch: 103 traing_acc:0.822 tst_acc:0.711
# epoch: 104 traing_acc:0.756 tst_acc:0.844
# epoch: 105 traing_acc:0.800 tst_acc:0.667
# epoch: 106 traing_acc:0.644 tst_acc:0.711
# epoch: 107 traing_acc:0.867 tst_acc:0.800
# epoch: 108 traing_acc:0.756 tst_acc:0.889
# epoch: 109 traing_acc:0.800 tst_acc:0.756
# epoch: 110 traing_acc:0.800 tst_acc:0.756
# epoch: 111 traing_acc:0.844 tst_acc:0.600
# epoch: 112 traing_acc:0.756 tst_acc:0.756
# epoch: 113 traing_acc:0.800 tst_acc:0.600
# epoch: 114 traing_acc:0.867 tst_acc:0.556
# epoch: 115 traing_acc:0.733 tst_acc:0.689
# epoch: 116 traing_acc:0.756 tst_acc:0.600
# epoch: 117 traing_acc:0.756 tst_acc:0.711
# epoch: 118 traing_acc:0.733 tst_acc:0.667
# epoch: 119 traing_acc:0.889 tst_acc:0.778
# epoch: 120 traing_acc:0.711 tst_acc:0.689
# epoch: 121 traing_acc:0.778 tst_acc:0.778
# epoch: 122 traing_acc:0.822 tst_acc:0.867
# epoch: 123 traing_acc:0.800 tst_acc:0.689
# epoch: 124 traing_acc:0.689 tst_acc:0.711
# epoch: 125 traing_acc:0.733 tst_acc:0.756
# epoch: 126 traing_acc:0.711 tst_acc:0.711
# epoch: 127 traing_acc:0.778 tst_acc:0.778
# epoch: 128 traing_acc:0.889 tst_acc:0.778
# epoch: 129 traing_acc:0.822 tst_acc:0.867
# epoch: 130 traing_acc:0.800 tst_acc:0.711
# epoch: 131 traing_acc:0.778 tst_acc:0.733
# epoch: 132 traing_acc:0.889 tst_acc:0.733
# epoch: 133 traing_acc:0.756 tst_acc:0.600
# epoch: 134 traing_acc:0.822 tst_acc:0.711
# epoch: 135 traing_acc:0.778 tst_acc:0.511
# epoch: 136 traing_acc:0.756 tst_acc:0.600
# epoch: 137 traing_acc:0.911 tst_acc:0.756
# epoch: 138 traing_acc:0.911 tst_acc:0.756
# epoch: 139 traing_acc:0.800 tst_acc:0.756
# epoch: 140 traing_acc:0.778 tst_acc:0.600
# epoch: 141 traing_acc:0.733 tst_acc:0.511
# epoch: 142 traing_acc:0.800 tst_acc:0.711
# epoch: 143 traing_acc:0.778 tst_acc:0.511
# epoch: 144 traing_acc:0.800 tst_acc:0.844
# epoch: 145 traing_acc:0.822 tst_acc:0.600
# epoch: 146 traing_acc:0.933 tst_acc:0.778
# epoch: 147 traing_acc:0.844 tst_acc:0.867
# epoch: 148 traing_acc:0.778 tst_acc:0.667
# epoch: 149 traing_acc:0.844 tst_acc:0.778
# epoch: 150 traing_acc:0.733 tst_acc:0.511
# epoch: 151 traing_acc:0.822 tst_acc:0.711
# epoch: 152 traing_acc:0.822 tst_acc:0.756
# epoch: 153 traing_acc:0.800 tst_acc:0.711
# epoch: 154 traing_acc:0.911 tst_acc:0.689
# epoch: 155 traing_acc:0.778 tst_acc:0.756
# epoch: 156 traing_acc:0.778 tst_acc:0.689
# epoch: 157 traing_acc:0.800 tst_acc:0.756
# epoch: 158 traing_acc:0.756 tst_acc:0.778
# epoch: 159 traing_acc:0.889 tst_acc:0.689
# epoch: 160 traing_acc:0.778 tst_acc:0.756
# epoch: 161 traing_acc:0.844 tst_acc:0.733
# epoch: 162 traing_acc:0.822 tst_acc:0.644
# epoch: 163 traing_acc:0.756 tst_acc:0.711
# epoch: 164 traing_acc:0.911 tst_acc:0.578
# epoch: 165 traing_acc:0.889 tst_acc:0.600
# epoch: 166 traing_acc:0.800 tst_acc:0.733
# epoch: 167 traing_acc:0.800 tst_acc:0.689
# epoch: 168 traing_acc:0.822 tst_acc:0.644
# epoch: 169 traing_acc:0.778 tst_acc:0.756
# epoch: 170 traing_acc:0.867 tst_acc:0.756
# epoch: 171 traing_acc:0.911 tst_acc:0.956
# epoch: 172 traing_acc:0.756 tst_acc:0.822
# epoch: 173 traing_acc:0.800 tst_acc:0.756
# epoch: 174 traing_acc:0.822 tst_acc:0.756
# epoch: 175 traing_acc:0.933 tst_acc:0.733
# epoch: 176 traing_acc:0.756 tst_acc:0.889
# epoch: 177 traing_acc:0.911 tst_acc:0.822
# epoch: 178 traing_acc:0.911 tst_acc:0.756
# epoch: 179 traing_acc:0.778 tst_acc:0.756
# epoch: 180 traing_acc:0.822 tst_acc:0.756
# epoch: 181 traing_acc:0.756 tst_acc:0.822
# epoch: 182 traing_acc:0.844 tst_acc:0.689
# epoch: 183 traing_acc:0.844 tst_acc:0.733
# epoch: 184 traing_acc:0.733 tst_acc:0.756
# epoch: 185 traing_acc:0.822 tst_acc:0.600
# epoch: 186 traing_acc:0.889 tst_acc:0.756
# epoch: 187 traing_acc:0.844 tst_acc:0.711
# epoch: 188 traing_acc:0.711 tst_acc:0.689
# epoch: 189 traing_acc:0.822 tst_acc:0.733
# epoch: 190 traing_acc:0.800 tst_acc:0.733
# epoch: 191 traing_acc:0.844 tst_acc:0.600
# epoch: 192 traing_acc:0.756 tst_acc:0.756
# epoch: 193 traing_acc:0.844 tst_acc:0.778
# epoch: 194 traing_acc:0.844 tst_acc:0.956
# epoch: 195 traing_acc:0.822 tst_acc:0.622
# epoch: 196 traing_acc:0.778 tst_acc:0.600
# epoch: 197 traing_acc:0.800 tst_acc:0.867
# epoch: 198 traing_acc:0.711 tst_acc:0.600
# epoch: 199 traing_acc:0.778 tst_acc:0.711
# [[-8.41542265e+00 -8.40117822e+00 -8.41196965e+00]
#  [ 3.76293586e-02 -6.97365752e-03  6.56032023e-04]
#  [-3.63162564e-02  3.24515651e-02  1.08198148e-02]
#  [-3.75527244e-02  1.19164480e-02  4.57254321e-02]
#  [ 7.61037725e-03  1.21675016e-03  4.43863233e-03]]
# [-8.41542265e+00  3.76293586e-02 -3.63162564e-02 -3.75527244e-02
#   7.61037725e-03]
